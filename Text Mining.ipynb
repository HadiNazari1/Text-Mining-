# %%
import pandas as pd

# %%
data = pd. read_csv("per.csv")
data.head()
# Out:
#    NewsID                                              Title  \
# 0  843656  \nوزير علوم درجمع استادان نمونه: سن بازنشستگي ...
# 1  837144  \nگردهمايي دانش‌آموختگان موسسه آموزش عالي سوره...
# 2  436862  \nنتايج آزمون دوره‌هاي فراگير دانشگاه پيام‌نور...
# 3  227781  \nهمايش يكروزه آسيب شناسي مفهوم روابط عمومي در...
# 4  174187  \nوضعيت اقتصادي و ميزان تحصيلات والدين از مهمت...
#
#                                                 Body         Date       Time  \
# 0  \nوزير علوم در جمع استادان نمونه كشور گفت: از ...  \n138/5//09  \n0:9::18
# 1  \nبه گزارش سرويس صنفي آموزشي خبرگزاري دانشجويا...  \n138/5//09  \n1:4::11
# 2  \nنتايج آزمون دوره‌هاي فراگير مقاطع كارشناسي و...  \n138/3//07  \n1:0::03
# 3                                                 \n  \n138/2//02  \n1:3::42
# 4  \nمحمدتقي علوي يزدي، مجري اين طرح پژوهشي در اي...  \n138/1//08  \n1:1::49
#
#              Category  Category2
# 0           \nآموزشي-   \nآموزشي
# 1           \nآموزشي-   \nآموزشي
# ...

# %%
with open('stopwords.txt', encoding='utf-8-sig') as stopwords_file:
    stopwords = stopwords_file.readlines()

stopwords = [line.strip() for line in stopwords]

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hadin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
nltk_stopwords= nltk.corpus.stopwords.words('english')
stopwords.extend(nltk_stopwords)

# %%
import hazm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 import hazm
#
# ModuleNotFoundError: No module named 'hazm'

# %%
dataset= pd.DataFrame(columns=('title_body','category')) 
for index, row in data.iterrows():
    title_body = row['Title'] + ' ' + row['Body']
    title_body_tokenized=word_tokenized(title_body)
    title_body_tokenized_filtered=[w for w in titile_body_tokenized if not w in stopwords]
    datasets.loc[index] = {
        'title_body' : ' ' .join(title_body_tokenized_filtered),
        'category' : row ['Category2']. replace('\n', ' ')
    }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 4
#       2 for index, row in data.iterrows():
#       3     title_body = row['Title'] + ' ' + row['Body']
# ----> 4     title_body_tokenized=word_tokenized(title_body)
#       5     title_body_tokenized_filtered=[w for w in titile_body_tokenized if not w in stopwords]
#       6     datasets.loc[index] = {
#       7         'title_body' : ' ' .join(title_body_tokenized_filtered),
#       8         'category' : row ['Category2']. replace('\n', ' ')
#       9     }
#
# NameError: name 'word_tokenized' is not defined
